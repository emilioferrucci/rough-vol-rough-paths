# %% [markdown]
# TODO list:
#
# - Remind myself what the problem was
# - Check to see that what virtualBrownianTree is doing as an interpolation
# - Make piecewise linear control
# - Get rid of dense solutions, so we can solve at arbitrary precision
# - Try to use built in Euler scheme
# - If doesn't work, code Euler manually
